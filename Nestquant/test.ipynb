# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

# %%
data = pd.read_parquet('YEAR_AND_MONTH=201902.parquet')
data
# Out:
#                   OPEN     HIGH      LOW    CLOSE      VOLUME  \
# OPEN_TIME
# 1548979200000  3434.10  3439.50  3430.83  3435.82  123.670606
# 1548979500000  3435.82  3440.15  3433.29  3434.33   85.904042
# 1548979800000  3434.33  3437.99  3431.40  3434.34  128.085390
# 1548980100000  3434.32  3435.95  3428.75  3431.58  134.001998
# 1548980400000  3430.16  3434.65  3427.00  3429.39  168.875958
# ...                ...      ...      ...      ...         ...
# 1551396900000  3813.45  3815.98  3811.88  3814.92   33.837916
# 1551397200000  3814.93  3816.91  3812.58  3815.29   34.274296
# 1551397500000  3815.98  3816.91  3813.66  3816.25   38.548717
# 1551397800000  3816.21  3818.95  3815.61  3815.66   35.407751
# 1551398100000  3815.92  3816.77  3811.49  3813.69   38.781718
#
#                QUOTE_ASSET_VOLUME  NUMBER_OF_TRADES  \
# OPEN_TIME
# 1548979200000       424864.172010               802
# 1548979500000       295293.542178               640
# ...
